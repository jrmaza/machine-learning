# %% [markdown]
# <a href="https://colab.research.google.com/github/jrmaza/machine-learning/blob/main/diabetes_redesneuronales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Diabetes gestacional con redes neuronales

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/jrmaza/datasets/main/pima-indians-diabetes.csv'
diabetes = pd.read_csv(url)
diabetes
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
diabetes.columns = ['preg','glu','pre','ski','desc1','desc2','desc3','age','diagnosis']
diabetes
x = diabetes.drop(['diagnosis'], axis=1)
x
# Out:
#      preg  glu  pre  ski  desc1  desc2  desc3  age
# 0       1   85   66   29      0   26.6  0.351   31
# 1       8  183   64    0      0   23.3  0.672   32
# 2       1   89   66   23     94   28.1  0.167   21
# 3       0  137   40   35    168   43.1  2.288   33
# 4       5  116   74    0      0   25.6  0.201   30
# ..    ...  ...  ...  ...    ...    ...    ...  ...
# 762    10  101   76   48    180   32.9  0.171   63
# 763     2  122   70   27      0   36.8  0.340   27
# 764     5  121   72   23    112   26.2  0.245   30
# 765     1  126   60    0      0   30.1  0.349   47
# 766     1   93   70   31      0   30.4  0.315   23
#
# [767 rows x 8 columns]

# %%
y = diabetes.drop(['preg', 	'glu', 	'pre', 	'ski', 	'desc1', 	'desc2', 	'desc3', 	'age'], axis=1)
y
# Out:
#      diagnosis
# 0            0
# 1            1
# 2            0
# 3            1
# 4            0
# ..         ...
# 762          0
# 763          0
# 764          0
# 765          1
# 766          0
#
# [767 rows x 1 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf

# %%
modelo_diabetes = Sequential()
modelo_diabetes.add(Dense(12, input_shape=(8,), activation='relu'))
modelo_diabetes.add(Dense(8, activation='relu'))
#modelo_diabetes.add(Dense(4, activation='relu'))
modelo_diabetes.add(Dense(1, activation='sigmoid')) # -> sigmoid los datos son binarios 0 y 1

#12-8-1

# %%
modelo_diabetes.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
resultado = modelo_diabetes.fit(x,y, epochs=500, batch_size=10)

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de pérdida")
plt.plot(resultado.history["loss"])

# %% [markdown]
# ## Actividad
# Probar por lo menos 4 combinaciones de capas ocultas con un número diferente de neuronas y entrenar el modelo hasta 1500 epochs y reportar gráfica de pérdida para cada una de las combinaciones y decidir cuál es la mejor combi.
# Compartir el colab a juliomaza@mail.uniatlantico.edu.co
